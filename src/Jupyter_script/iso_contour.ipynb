# %%
# %load_ext autoreload
# %autoreload 2
from src.Field.post_process import PostProcess

post_processing = PostProcess(0.4, 1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
post_processing.plot_alpha()

# %%
post_processing.plot('ur')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 post_processing.plot('ur')
#
# File ~\Documents\M2\Prog_Mod\Jet_Turbulent\src\Field\post_process.py:77, in PostProcess.plot(self, name_value, x_min, x_max, r_min, r_max)
#      74 if r_min < 0 or r_max > 20:
#      75     raise ValueError("r_min and r_max must be between 0 and 20")
# ---> 77 x, r, value = self.get_value_in_field(name_value, x_min=x_min, x_max=x_max, r_min=r_min, r_max=r_max)
#      78 plt.style.use('ggplot')
#      79 fig, ax = plt.subplots(figsize=RANS_FIGSIZE, layout='constrained')
#
# File ~\Documents\M2\Prog_Mod\Jet_Turbulent\src\Field\post_process.py:144, in PostProcess.get_value_in_field(self, value, x_min, x_max, r_min, r_max)
#     142 x_mask = (self.x_grid.iloc[:, 0] >= x_min) & (self.x_grid.iloc[:, 0] <= x_max)
#     143 r_mask = (self.r_grid.iloc[0, :] >= r_min) & (self.r_grid.iloc[0, :] <= r_max)
# --> 144 value = self.rans_field[value]
#     145 # Apply the masks to select the subarray
#     146 x_sub = self.x_grid.loc[x_mask, r_mask]
#
# TypeError: 'NoneType' object is not subscriptable
