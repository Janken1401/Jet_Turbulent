# %%
# %load_ext autoreload
# %autoreload 2
from src.Field.perturbation_field import Perturbationfield
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pert_field = Perturbationfield()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pert_field = Perturbationfield()
#
# File ~\Documents\M2\Prog_Mod\Jet_Turbulent\src\Field\perturbation_field.py:30, in Perturbationfield.__init__(self, St, ID_MACH)
#      28 self.pert_values = self.get_perturbation_field()
#      29 self.x_grid, self.r_grid = self.grid()
# ---> 30 self.rans_values = self.interpolate_to_pse_grid()
#
# File ~\Documents\M2\Prog_Mod\Jet_Turbulent\src\Field\perturbation_field.py:42, in Perturbationfield.interpolate_to_pse_grid(self)
#      39 interpolated_field = np.zeros((len(self.x_grid), len(r_grid)))
#      41 for i, r_val in enumerate(r_grid):
# ---> 42     rans_values_at_r = self.rans_field.values[value].iloc[:, i]
#      43     rans_x_at_r = rans_x_values[i]
#      45     cs = CubicSpline(rans_x_at_r, rans_values_at_r)
#
# KeyError: 'ut'

# %%
pert_field.plot_mean('ux')
