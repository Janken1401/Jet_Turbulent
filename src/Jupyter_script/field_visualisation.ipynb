# %%
# %load_ext autoreload
# %autoreload 2
from src.Field.post_process import PostProcess
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pert_field = PostProcess(0.4, 1)

# %%
pert_field.plot('ur', x_min=2,x_max=2.5)
